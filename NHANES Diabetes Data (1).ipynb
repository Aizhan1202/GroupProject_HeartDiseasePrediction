# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cdc_merged_bulk.csv', index_col=0)

# %%
df.corr()['HasDiabetes'].abs().sort_values(ascending=False)
# Out:
# HasDiabetes    1.000000
# LBXGH          0.758304
# BMXWAIST       0.245221
# BMXBMI         0.203290
# BMXARMC        0.171884
# BMXWT          0.164759
# BMDSTATS       0.160523
# BMXLEG         0.147735
# BMIWT          0.146183
# BMITRI         0.143733
# BMXSUB         0.136021
# BMXTRI         0.076353
# BMXARML        0.057625
# BMXHT          0.029685
# BMISUB         0.022069
# BMIHT          0.006953
# SEQN           0.003782
# BMXRECUM            NaN
# BMIRECUM            NaN
# BMXHEAD             NaN
# BMIHEAD             NaN
# BMILEG              NaN
# BMIARML             NaN
# BMIARMC             NaN
# BMIWAIST            NaN
# Name: HasDiabetes, dtype: float64

# %%
df
# Out:
#          SEQN  LBXGH  BMDSTATS  BMXWT  BMIWT  BMXRECUM  BMIRECUM  BMXHEAD  \
# 0     41475.0    5.7       3.0  138.9    NaN       NaN       NaN      NaN
# 1     41477.0    9.5       1.0   83.9    NaN       NaN       NaN      NaN
# 2     41479.0    5.7       1.0   65.7    NaN       NaN       NaN      NaN
# 3     41481.0    NaN       1.0   77.9    NaN       NaN       NaN      NaN
# 4     41482.0    7.0       1.0  101.6    NaN       NaN       NaN      NaN
# ...       ...    ...       ...    ...    ...       ...       ...      ...
# 6912  51619.0    5.3       1.0   89.4    NaN       NaN       NaN      NaN
# 6913  51620.0    5.4       1.0   72.2    NaN       NaN       NaN      NaN
# 6914  51621.0    4.9       1.0   42.8    NaN       NaN       NaN      NaN
# 6915  51622.0    4.8       1.0   79.1    NaN       NaN       NaN      NaN
# 6916  51623.0    5.4       1.0   85.2    NaN       NaN       NaN      NaN
#
#       BMIHEAD  BMXHT  ...  BMIARML  BMXARMC  BMIARMC  BMXWAIST  BMIWAIST  \
# ...

# %%
key_columns = ['LBXGH', 'BMXWAIST', 'BMXBMI']

# %%
key_columns
# Out:
# ['LBXGH', 'BMXWAIST', 'BMXBMI']

# %%
df[key_columns]
# Out:
#       LBXGH  BMXWAIST  BMXBMI
# 0       5.7     156.3   58.04
# 1       9.5     109.5   30.05
# 2       5.7      95.4   27.56
# 3       NaN      79.5   23.34
# 4       7.0     117.0   33.64
# ...     ...       ...     ...
# 6912    5.3     108.5   30.08
# 6913    5.4     101.1   28.31
# 6914    4.9      69.4   17.72
# 6915    4.8     111.9   31.53
# 6916    5.4     116.2   32.27
#
# [6917 rows x 3 columns]

# %%
df.rename(columns={'LBXGH': 'Glucose', 'BMXWAIST': "Waist", 'BMXBMI': 'BMI'}, inplace=True)

# %%
df_mini = df[['Glucose', 'Waist', 'BMI', "HasDiabetes"]]

# %%
df_mini
# Out:
#       Glucose  Waist    BMI  HasDiabetes
# 0         5.7  156.3  58.04            0
# 1         9.5  109.5  30.05            1
# 2         5.7   95.4  27.56            0
# 3         NaN   79.5  23.34            0
# 4         7.0  117.0  33.64            1
# ...       ...    ...    ...          ...
# 6912      5.3  108.5  30.08            0
# 6913      5.4  101.1  28.31            0
# 6914      4.9   69.4  17.72            0
# 6915      4.8  111.9  31.53            0
# 6916      5.4  116.2  32.27            0
#
# [6917 rows x 4 columns]

# %%
df_mini.HasDiabetes.hist()
plt.show()

# %%
sns.boxplot(x="HasDiabetes", y="BMI", data=df_mini, palette="Set1")
# Out:
# <AxesSubplot:xlabel='HasDiabetes', ylabel='BMI'>

# %%
sns.boxplot(x="HasDiabetes", y="Waist", data=df_mini, palette="Set1")
# Out:
# <AxesSubplot:xlabel='HasDiabetes', ylabel='Waist'>

# %%
sns.boxplot(x="HasDiabetes", y="Glucose", data=df_mini, palette="Set1")
# Out:
# <AxesSubplot:xlabel='HasDiabetes', ylabel='Glucose'>

# %%
df_pa = pd.read_sas('PAQ_E.XPT')

# %%
df_pa
# Out:
#          SEQN  PAQ560  PAD590        PAD600  PAQ605  PAQ610  PAD615  PAQ620  \
# 0     41475.0     NaN     NaN           NaN     2.0     NaN     NaN     2.0
# 1     41476.0     7.0     2.0  5.397605e-79     NaN     NaN     NaN     NaN
# 2     41477.0     NaN     NaN           NaN     2.0     NaN     NaN     2.0
# 3     41479.0     NaN     NaN           NaN     2.0     NaN     NaN     1.0
# 4     41480.0     7.0     1.0  6.000000e+00     NaN     NaN     NaN     NaN
# ...       ...     ...     ...           ...     ...     ...     ...     ...
# 9354  51619.0     NaN     NaN           NaN     1.0     5.0   300.0     1.0
# 9355  51620.0     NaN     NaN           NaN     1.0     2.0    60.0     1.0
# 9356  51621.0     NaN     NaN           NaN     2.0     NaN     NaN     2.0
# 9357  51622.0     NaN     NaN           NaN     2.0     NaN     NaN     2.0
# 9358  51623.0     NaN     NaN           NaN     2.0     NaN     NaN     2.0
#
# ...

# %%
df = df.merge(df_pa, on='SEQN', how='inner')

# %%
df
# Out:
#          SEQN  Glucose  BMDSTATS  BMXWT  BMIWT  BMXRECUM  BMIRECUM  BMXHEAD  \
# 0     41475.0      5.7       3.0  138.9    NaN       NaN       NaN      NaN
# 1     41477.0      9.5       1.0   83.9    NaN       NaN       NaN      NaN
# 2     41479.0      5.7       1.0   65.7    NaN       NaN       NaN      NaN
# 3     41481.0      NaN       1.0   77.9    NaN       NaN       NaN      NaN
# 4     41482.0      7.0       1.0  101.6    NaN       NaN       NaN      NaN
# ...       ...      ...       ...    ...    ...       ...       ...      ...
# 6912  51619.0      5.3       1.0   89.4    NaN       NaN       NaN      NaN
# 6913  51620.0      5.4       1.0   72.2    NaN       NaN       NaN      NaN
# 6914  51621.0      4.9       1.0   42.8    NaN       NaN       NaN      NaN
# 6915  51622.0      4.8       1.0   79.1    NaN       NaN       NaN      NaN
# 6916  51623.0      5.4       1.0   85.2    NaN       NaN       NaN      NaN
#
# ...

# %%
df.corr().HasDiabetes.abs().sort_values(ascending=False)
# Out:
# HasDiabetes    1.000000
# Glucose        0.758304
# Waist          0.245221
# BMI            0.203290
# BMXARMC        0.171884
# BMXWT          0.164759
# BMDSTATS       0.160523
# BMXLEG         0.147735
# BMIWT          0.146183
# BMITRI         0.143733
# BMXSUB         0.136021
# PAQ650         0.134499
# PAAQUEX        0.091450
# PAQ665         0.089002
# BMXTRI         0.076353
# PAQ620         0.068228
# PAQ605         0.059461
# BMXARML        0.057625
# PAQ635         0.056492
# PAD615         0.033120
# BMXHT          0.029685
# PAQ655         0.023657
# PAD645         0.022543
# BMISUB         0.022069
# PAD630         0.020024
# PAD675         0.016439
# PAQ640         0.016436
# PAQ670         0.009517
# PAD660         0.008405
# BMIHT          0.006953
# PAD680         0.004061
# PAQ625         0.003821
# SEQN           0.003782
# PAQ610         0.003222
# BMXRECUM            NaN
# BMIRECUM            NaN
# BMXHEAD             NaN
# BMIHEAD             NaN
# ...

# %%
# demographic
df_demo = pd.read_sas('DEMO_E.XPT')
# blood pressure questionaire
df_bp = pd.read_sas('BPQ_E.XPT')
# blood pressure results
df_bpr = pd.read_sas('BPX_E.XPT')
# medical conditions
df_mc = pd.read_sas('MCQ_E.XPT')
# depression dataset
#pd.read_sas('DPQ_E.XPT')
# income dataset
#pd.read_sas('INQ.XPT')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-230-8f6c73456c69> in <module>
#       6 df_bpr = pd.read_sas('BPX_E.XPT')
#       7 # medical conditions
# ----> 8 df_mc = pd.read_sas('MCQ_E.XPT')
#       9 # depression dataset
#      10 #pd.read_sas('DPQ_E.XPT')
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/sas/sasreader.py in read_sas(filepath_or_buffer, format, index, encoding, chunksize, iterator)
#     115
#     116         reader = XportReader(
# --> 117             filepath_or_buffer, index=index, encoding=encoding, chunksize=chunksize
#     118         )
#     119     elif format.lower() == "sas7bdat":
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/sas/sas_xport.py in __init__(self, filepath_or_buffer, index, encoding, chunksize)
#     262
#     263         if isinstance(filepath_or_buffer, (str, bytes)):
# ...

# %%
df = df.merge(df_demo, on='SEQN', how='inner')

# %%
df = df.merge(df_bp, on='SEQN', how='inner')

# %%
df = df.merge(df_bpr, on='SEQN', how='inner')

# %%
df.corr().HasDiabetes.abs().sort_values(ascending=False)[1:50]
# Out:
# Glucose     0.758712
# RIDAGEEX    0.247527
# RIDAGEMN    0.246878
# Waist       0.239251
# RIDAGEYR    0.229782
# BMI         0.196250
# BPXSY4      0.191452
# BPQ020      0.182415
# DMDHRAGE    0.178790
# BPXSY2      0.169702
# BPXSY1      0.164679
# BMXARMC     0.161527
# BMDSTATS    0.156421
# BPXML1      0.155064
# BPXSY3      0.154798
# BMXWT       0.153756
# BMXLEG      0.149603
# PEASCCT1    0.149365
# BPACSZ      0.144752
# BMITRI      0.142049
# BMIWT       0.140176
# WTINT2YR    0.128802
# BMXSUB      0.127820
# WTMEC2YR    0.127604
# BPQ090D     0.125283
# PAQ650      0.120156
# DMDHSEDU    0.113604
# BPQ090B     0.110659
# DMDEDUC2    0.110047
# BPQ090C     0.108813
# BPQ070      0.102352
# BPQ100D     0.101401
# BPQ040A     0.093985
# DMDHREDU    0.091507
# BPXPLS      0.086741
# PAQ665      0.083994
# BPXDI4      0.073217
# BMXTRI      0.072013
# BPQ050A     0.070653
# PAQ620      0.069654
# PAQ605      0.065201
# BPQ060      0.063246
# BPQ080      0.062625
# ...

# %%
# RIDAGEYR - AGE
# Waist
# BMI
# BPXSY1 - Systolic Blood Pressure 1st Reading (4th is Higher but might no exist for majority)
# PAQ650 - Days vigorous recreational activities

# %%
df_corr = df[['RIDAGEYR', 'Waist', 'BMI', 'BPXSY1', 'PAQ650', 'HasDiabetes']]

# %%
df_corr.isnull().sum()
# Out:
# RIDAGEYR         0
# Waist          362
# BMI            118
# BPXSY1         475
# PAQ650           0
# HasDiabetes      0
# dtype: int64

# %%
df_final = df_corr.dropna()

# %%
df_final
# Out:
#       RIDAGEYR  Waist    BMI  BPXSY1  PAQ650  HasDiabetes
# 0         62.0  156.3  58.04   128.0     2.0            0
# 1         71.0  109.5  30.05   144.0     2.0            1
# 2         52.0   95.4  27.56   112.0     2.0            0
# 3         21.0   79.5  23.34   112.0     1.0            0
# 4         64.0  117.0  33.64   116.0     2.0            1
# ...        ...    ...    ...     ...     ...          ...
# 6302      61.0  108.5  30.08   152.0     2.0            0
# 6303      50.0  101.1  28.31    96.0     2.0            0
# 6304      17.0   69.4  17.72   122.0     1.0            0
# 6305      60.0  111.9  31.53   148.0     2.0            0
# 6306      72.0  116.2  32.27   112.0     2.0            0
#
# [5599 rows x 6 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5599 entries, 0 to 6306
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   RIDAGEYR     5599 non-null   float64
#  1   Waist        5599 non-null   float64
#  2   BMI          5599 non-null   float64
#  3   BPXSY1       5599 non-null   float64
#  4   PAQ650       5599 non-null   float64
#  5   HasDiabetes  5599 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 306.2 KB

# %%
df_final.HasDiabetes.hist()
# Out:
# <AxesSubplot:>

# %%
df_final = df_final.rename(columns={'RIDAGEYR': 'Age', 'BPXSY1': 'SystolicBloodPressure', 'PAQ650': 'DaysVigorousExercise'})

# %%
df_final
# Out:
#        Age  Waist    BMI  SystolicBloodPressure  DaysVigorousExercise  \
# 0     62.0  156.3  58.04                  128.0                   2.0
# 1     71.0  109.5  30.05                  144.0                   2.0
# 2     52.0   95.4  27.56                  112.0                   2.0
# 3     21.0   79.5  23.34                  112.0                   1.0
# 4     64.0  117.0  33.64                  116.0                   2.0
# ...    ...    ...    ...                    ...                   ...
# 6302  61.0  108.5  30.08                  152.0                   2.0
# 6303  50.0  101.1  28.31                   96.0                   2.0
# 6304  17.0   69.4  17.72                  122.0                   1.0
# 6305  60.0  111.9  31.53                  148.0                   2.0
# 6306  72.0  116.2  32.27                  112.0                   2.0
#
#       HasDiabetes
# 0               0
# 1               1
# 2               0
# 3               0
# 4               1
# ...

# %%
df_final.corr()['HasDiabetes']
# Out:
# Age                      0.225826
# Waist                    0.239284
# BMI                      0.203183
# SystolicBloodPressure    0.164558
# DaysVigorousExercise     0.120004
# HasDiabetes              1.000000
# Name: HasDiabetes, dtype: float64

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
#from xgboost import XGBClassifier
#from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, \
    classification_report
from sklearn.model_selection import train_test_split, KFold
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
x = df_final[df_final.columns[:-1]]
y = df_final['HasDiabetes']

# %%
x
# Out:
#        Age  Waist    BMI  SystolicBloodPressure  DaysVigorousExercise
# 0     62.0  156.3  58.04                  128.0                   2.0
# 1     71.0  109.5  30.05                  144.0                   2.0
# 2     52.0   95.4  27.56                  112.0                   2.0
# 3     21.0   79.5  23.34                  112.0                   1.0
# 4     64.0  117.0  33.64                  116.0                   2.0
# ...    ...    ...    ...                    ...                   ...
# 6302  61.0  108.5  30.08                  152.0                   2.0
# 6303  50.0  101.1  28.31                   96.0                   2.0
# 6304  17.0   69.4  17.72                  122.0                   1.0
# 6305  60.0  111.9  31.53                  148.0                   2.0
# 6306  72.0  116.2  32.27                  112.0                   2.0
#
# [5599 rows x 5 columns]

# %%
y
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       1
#        ..
# 6302    0
# 6303    0
# 6304    0
# 6305    0
# 6306    0
# Name: HasDiabetes, Length: 5599, dtype: int64

# %%
models = [('LR', LogisticRegression()),
          ('KNN', KNeighborsClassifier()),
          ('CART', DecisionTreeClassifier()),
          ('RF', RandomForestClassifier()),
          ('SVR', SVC(gamma='auto')),
          ('GB',GradientBoostingClassifier())]

# evaluate each model in turn
results = []
names = []

for name, model in models:
    kfold = KFold(n_splits=10, random_state=None)
    cv_results = cross_val_score(model, x, y, cv=kfold, scoring="accuracy")
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.900520 (0.015760)
# KNN: 0.887839 (0.013370)
# CART: 0.833008 (0.018195)
# RF: 0.894982 (0.013773)
# SVR: 0.901592 (0.015149)
# GB: 0.899090 (0.014239)

# %%
# LR
train, test = train_test_split(df_final, test_size=0.3, random_state=0, stratify=y)
train_x = train[train.columns[:-1]]
test_x = test[test.columns[:-1]]
train_y = train['HasDiabetes']
test_y = test['HasDiabetes']

lr_model = LogisticRegression()

lr_model.fit(train_x, train_y)

prediction = lr_model.predict(test_x)

metrics.accuracy_score(prediction, test_y)

metrics.confusion_matrix(prediction, test_y)
# Out:
# array([[1503,  158],
#        [  13,    6]])

# %%
svr_model = SVC(gamma='auto')

# %%
svr_model.fit(train_x, train_y)
# Out:
# SVC(gamma='auto')

# %%
prediction_svr = svr_model.predict(test_x)

metrics.accuracy_score(prediction_svr, test_y)

metrics.confusion_matrix(prediction_svr, test_y)
# Out:
# array([[1515,  164],
#        [   1,    0]])

# %%
tn, fp, fn, tp = metrics.confusion_matrix(prediction_svr, test_y).ravel()

# %%
# Decision Tree

# %%
cart_model = DecisionTreeClassifier()

# %%
cart_model.fit(train_x, train_y)
# Out:
# DecisionTreeClassifier()

# %%
prediction_cart = cart_model.predict(test_x)

metrics.accuracy_score(prediction_cart, test_y)

metrics.confusion_matrix(prediction_cart, test_y)
# Out:
# array([[1360,  130],
#        [ 156,   34]])
